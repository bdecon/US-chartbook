# %%
import sys
sys.path.append('../src')

import uschartbook.config

from uschartbook.config import *
from uschartbook.utils import *

# %%
# Request data from BEA API

table_list = ['T20304', 'T70100', 'T10101', 'T10502', 
              'T11706', 'T11000', 'T20100']


#api_results = bea_api_nipa(table_list, bea_key)

#bea_to_db(api_results)

# %%
retrieve_table('T10502')
# Out:
# {'Statistic': 'NIPA Table',
#  'UTCProductionTime': '2019-08-24T03:23:49.820',
#  'Dimensions': [{'Ordinal': '1',
#    'Name': 'TableName',
#    'DataType': 'string',
#    'IsValue': '0'},
#   {'Ordinal': '2', 'Name': 'SeriesCode', 'DataType': 'string', 'IsValue': '0'},
#   {'Ordinal': '3',
#    'Name': 'LineNumber',
#    'DataType': 'numeric',
#    'IsValue': '0'},
#   {'Ordinal': '4',
#    'Name': 'LineDescription',
#    'DataType': 'string',
#    'IsValue': '0'},
#   {'Ordinal': '5', 'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#   {'Ordinal': '6', 'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#   {'Ordinal': '7', 'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'},
#   {'Ordinal': '8',
#    'Name': 'METRIC_NAME',
#    'DataType': 'string',
#    'IsValue': '0'},
#   {'Ordinal': '9',
#    'Name': 'DataValue',
#    'DataType': 'numeric',
#    'IsValue': '1'}],
#  'Data': [{'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1994Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1996Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '6.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1997Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1997Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1998Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1999Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2001Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2002Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2002Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2003Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '7.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2004Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2005Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2007Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2007Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2008Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-2.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2009Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2010Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2012Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2012Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2013Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2014Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2015Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2017Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2017Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2018Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2019Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1994Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1995Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1996Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1996Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1998Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '6.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1999Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2000Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '7.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2001Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-1.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2001Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2004Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2005Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2006Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2006Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2007Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2009Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2010Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2011Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-1.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2011Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2012Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2014Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2015Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2016Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2016Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2017Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1994Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1994Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1995Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1997Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '5.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1998Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1999Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1999Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '7.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2000Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2002Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2003Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2004Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2004Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2005Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2006Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2008Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2009Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-4.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2009Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2010Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2011Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2013Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2014Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-1.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2014Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2015Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2016Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.9'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2018Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2019Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1995Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1995Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1996Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1997Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '6.8'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '1998Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2000Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2000Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2001Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-1.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2002Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2003Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2003Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '4.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2005Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2006Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2007Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2008Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-2.3'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2008Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-8.4'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2010Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.0'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2011Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2012Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.7'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2013Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.6'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2013Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '3.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2015Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '0.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2016Q3',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2017Q2',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.2'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2018Q1',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '2.5'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'A191RL',
#    'LineNumber': '1',
#    'LineDescription': 'Gross domestic product',
#    'TimePeriod': '2018Q4',
#    'METRIC_NAME': 'Fisher Quantity Index',
#    'CL_UNIT': 'Percent change, annual rate',
#    'UNIT_MULT': '0',
#    'DataValue': '1.1'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1995Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.66'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1995Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.82'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1996Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.58'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1997Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.21'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1998Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.63'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2000Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '4.05'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2000Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.27'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2001Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.89'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2002Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.35'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2003Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.26'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2003Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.85'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2005Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.78'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2006Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.63'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2007Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.52'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2008Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.74'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2008Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-2.38'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2010Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.80'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2011Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.07'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2012Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.41'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2013Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.44'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2013Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.31'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2015Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.20'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2016Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.74'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2017Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.63'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2018Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.15'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2018Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.97'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1994Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.98'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1994Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.83'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1995Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.38'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1997Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '4.40'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1998Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '4.56'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1999Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.54'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1999Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.91'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2000Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.58'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2002Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.92'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2003Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.03'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2004Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.40'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2004Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.95'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2005Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.61'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2006Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.34'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2008Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.45'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2009Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.52'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2009Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.39'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2010Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.90'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2011Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.62'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2013Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.20'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2014Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.03'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2014Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.26'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2015Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.05'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2016Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.95'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2018Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.70'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2019Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.78'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1994Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.98'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1995Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.28'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1996Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.41'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1996Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.08'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1998Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.81'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '1999Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.00'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2000Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.63'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2001Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2001Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.95'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2004Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.99'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2005Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '3.03'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2006Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.98'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2006Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '2.63'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2007Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '1.52'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DPCERY',
#    'LineNumber': '2',
#    'LineDescription': 'Personal consumption expenditures',
#    'TimePeriod': '2009Q3',
# ...
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2012Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.03'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2014Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.09'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2015Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2016Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.21'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2016Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.17'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2017Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.19'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1995Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1995Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.10'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1996Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1997Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.12'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1998Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.00'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2000Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.20'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2000Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.22'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2001Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.06'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2002Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2003Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.17'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2003Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2005Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.24'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2006Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2007Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.10'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2008Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.11'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2008Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.29'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2010Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.15'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2011Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.08'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2012Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.12'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2013Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.07'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2013Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.15'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2015Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.02'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2016Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.12'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2017Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.09'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2018Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.12'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2018Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.07'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1994Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.27'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1996Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.11'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1997Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.16'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1997Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.00'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1998Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.16'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '1999Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.22'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2001Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.15'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2002Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.07'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2002Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.18'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2003Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.32'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2004Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.02'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2005Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.32'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2007Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.04'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2007Q4',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.08'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2008Q3',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '-0.34'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2009Q2',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.14'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2010Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.14'},
#   {'TableName': 'T10502',
#    'SeriesCode': 'DFXARY',
#    'LineNumber': '10',
#    'LineDescription': 'Food and beverages purchased for off-premises consumption',
#    'TimePeriod': '2012Q1',
#    'METRIC_NAME': 'Quantity Contributions',
#    'CL_UNIT': 'Level',
#    'UNIT_MULT': '0',
#    'DataValue': '0.14'},
#   ...],
#  'Notes': [{'NoteRef': 'T10502',
#    'NoteText': 'Table 1.5.2. Contributions to Percent Change in Real Gross Domestic Product, Expanded Detail  - LastRevised: July 26, 2019'},
#   {'NoteRef': 'T10502.1',
#    'NoteText': '1. Net expenses of NPISHs, defined as their gross operating expenses less primary sales to households.'},
#   {'NoteRef': 'T10502.2',
#    'NoteText': '2. Gross output is net of unrelated sales, secondary sales, and sales to business, to government, and to the rest of the world; excludes own-account investment (construction and software).'},
#   {'NoteRef': 'T10502.3',
#    'NoteText': '3. Excludes unrelated sales, secondary sales, and sales to business, to government, and to the rest of the world; includes membership dues and fees.'},
#   {'NoteRef': 'T10502.4',
#    'NoteText': '4. Excludes software embedded, or bundled, in computers and other equipment.'},
#   {'NoteRef': 'T10502.5',
#    'NoteText': '5. Research and development investment excludes expenditures for software development. Software development expenditures are included in software investment on line 38.'}]}
